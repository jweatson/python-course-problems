# %% [markdown]
# # Day 2 - PM Problem Set
# This session mainly involves around finishing up work on file handling, as well as work on the
#
# ## Problem 1 - Writing files
#
# - Modify the program in the last problem to write out the sorted list to a new file called "sorted.txt"
#
# ## Problem 2 - In introduction to libraries: `math`
#
# ### Background
# A very important thing about Python is that you _don't have to write everything yourself_, most routines or algorithms have already been written, and in some cases are written in other languages that are much faster than Python. If you think a solution to a problem you are working on exists within a library, it's always a good idea to check. But keep in mind that some of the more obscure libraries may not be installed on every computer. For this course we will only be using libraries that are used in almost every scientific python program, `math`, `numpy` and `matplotlib`.
#
# A good Python library also has good online documentation, which is a guide on how the library works, and how to use each function. It is highly recommended you use these sites for your work:
#
# - `math`: https://docs.python.org/3/library/math.html
# - `numpy`: https://numpy.org/doc/stable/user/index.html
# - `matplotlib`: https://matplotlib.org/stable/index.html
#
# ### Task
# - Write a basic program that imports the `math` library.
# - Using the `math` documentation, find the appropriate functions in the `math` library to calculate:
#   - The cosine of 60 degrees
#   - $e^2$
#   - $\log(1e3)$
#   - How many ways you can choose 3 things from 100 things without repeating yourself.
#   - The largest divisor in common with the following numbers: 210, 1008, 1764 and 74088.
#
# ### Hints
# - Trigonometric functions need the answer in radians, you can either calculate this value yourself, or better yet, find a function in `math` to convert degrees to radians.
# - These aren't mathematical functions you're going to be using all the time, but it's good to understand that even a very basic library like `math` can cover some very complex tasks quickly.

# %%
# Various math library functions.

# %% [markdown]
# ## Problem 3 - `numpy`
#
# ### Background
# `numpy`, in particular, is a very good example of a library that is much faster than if you were writing it yourself. A `numpy` array is similar to a list, but can only contain the same data type and generally being a bit more restriction. However, arrays are much faster at performing the same operation to a large dataset.
#
# ### Task
# - Write a program that creates a list from 1 to 100 million, then creates a new list from that previous list containing the square root of all the numbers in the original list.

# %%
# List from 1 to 100 milion.

# %% [markdown]
# - Add to the program a way of doing the same thing, but entirely using numpy, do not use loops or append data, this can all be done within a few lines of code.

# %%
# Using  Numpy

# %% [markdown]
# - Work out a way to calculate how long it takes to perform both sets of calculations, compare one with the other.

# %%
# Profiling and timing of both functions

# %% [markdown]
# ### Hints
# - As with the previous problem, it is best to consult the documentation, one function that might be useful is `numpy.arange()`, check the documentation on it.
# - The `time` library, specifically the function `time.time()` can be used to read the computers internal clock and store it as a `float`, subtracting a stop time from a start time can measure how long it takes to do something, this is a very basic form of what is called "profiling".
# - `numpy` has versions of the functions in `math`, which operate as quickly as possible on a `numpy` array.

# %% [markdown]
# ## Additional Work
#
# ### More `numpy`
#
# `numpy` has methods to read and write arrays, as well as sort and search.
#
# - Read in the file `random.txt` using `numpy` only, sorting it, and writing this to a file called `sorted_numpy.txt`.
#   - You will notice that this requires substantially less code to implement, as you don't have to write something to read in the file line-by-line.

# %%
# Reading in random with numpy, then sorting using numpy.

# %% [markdown]
# ### Classes and objects
#
# *Objects* are variables in some languages that have their own properties and methods, a *class* is used to describe an object, it acts as the blueprint for it. In the case of a sphere, for instance, a sphere has properties such as its radius, surface area and volume, a star can have radius, mass, luminosity, etc.
#
# - Write a class that can describe a sphere for a given radius. Describe its surface area and volume.

# %%
# Class describing a sphere

# %% [markdown]
# #### Hint
# The Python tutorial documentation is really helpful here! https://docs.python.org/3/tutorial/classes.html
#
# Keep in mind that classes are quite an advanced topic, and we won't need to use them for the rest of this course. They do come up quite often, for instance, most types of variable in Python are an object, such as a list.

# %% [markdown]
# # Day 1 - AM Problem Set

# %% [markdown]
# ## Problem 1 - Python Terminal
# - Using the python terminal, print the phrase "hello world".
#   - Or any other phrase you'd want to print, that's just usually the traditional one.
# - Get the python terminal to store a value, such as a number.
# - Then similarly to printing "hello world", print the stored value.

# %% [markdown]
# # Problem 2 - Writing and Executing a Python Program
# - Write a program below that also prints "hello world!"
# - Similarly, print a stored value using a program.

# %%
# Hello world program

# %%
# Storing values and printing

# %% [markdown]
# ### Notes
# - You'll see these are roughly the same, the obvious upshot of writing a program is that the program can be used again.
# - For most of this workshop, you can either use the Jupyter notebook the problem sheets are in, or write your own programs and run them through CoLab.

# %% [markdown]
# ## Problem 3 - Mathematical Operations and types
# - Perform some basic calculations with either a program or the Python terminal.
# - Experiment with the following operators in order to see what they do.
#
# ```python
# + -  * / % ** //
# ```
#
# - Which of the following are valid names for variables in Python?
#   1. x
#   2. 1
#   3. variable
#   4. 2variable
#   5. variable2
#   6. variable_2
#   7. variable-2
#   8. variable$
#   9. global
#   10. print
# - What data type are the following values? Which are not valid values?
#   1. 23
#   2. 23.5
#   3. "twenty three"
#   4. "23.5"
#   5. 2.3e1
#   6. e23
#   7. True
#   8. true
#
# ### Bonus questions
# - Which of the previous values can be converted into a `float`? Why is this?
# - What happens when the `float` values are converted into `int`?
# - Are `true` and `True` different, why is that?
# - What happens when `True` is converted into an `int`?

# %% [markdown]
# ## Problem 4 - Inputs
# - Write a program that takes an input from the user when it is run, asking them to enter a number and hit enter.
# - Write additional code to convert the input value in degrees Fahrenheit into degrees Celsius, and then print that out for the user.
# - Add instructions to the user that the program is to be used to calculate a temperature in Celsius from a temperature in Fahrenheit.
#
# ### Hints
# - The conversion value from Celsius to Fahrenheit is $T_F = (1.8 \times T_C) + 32$.
# - -40 in Celsius and Fahrenheit are the same temperature, 0 Celsius is 32 Fahrenheit, 100 Celsius is 212 Fahrenheit, use these to test your code.
# - The code may fail at the second step, this may have something to do with the input, make sure it is the right type (and what would be the right type?).

# %%
# Temperature conversion
